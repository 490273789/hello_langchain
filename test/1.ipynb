# %%
model = "openai:gpt-4o:1"
model_provider = model.split(":", maxsplit=1)[0]
model = ":".join(model.split(":")[1:])
print(model)
# Out:
# gpt-4o:1

# %% [markdown]
# 调整日志级别

# %%
import logging

logging.basicConfig(logging.DEBUG, format="%(asctime)s %(filename)s %(message)s")
