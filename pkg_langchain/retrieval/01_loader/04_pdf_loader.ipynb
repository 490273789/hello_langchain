# %% [markdown]
# 1.

# %%
from langchain_community.document_loaders import PyMuPDFLoader

# pdf比较复杂：有文字版本的、图片版本的、混合版本的
 
# 需要安装pymupdf
file_path = "../datas/Reflexion.pdf"

loader = PyMuPDFLoader(file_path)

docs = loader.load()

print(docs)
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-10-11T00:21:22+00:00', 'source': '../datas/Reflexion.pdf', 'file_path': '../datas/Reflexion.pdf', 'total_pages': 19, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-10-11T00:21:22+00:00', 'trapped': '', 'modDate': 'D:20231011002122Z', 'creationDate': 'D:20231011002122Z', 'page': 0}, page_content='Reflexion: Language Agents with\nVerbal Reinforcement Learning\nNoah Shinn\nNortheastern University\nnoahshinn024@gmail.com\nFederico Cassano\nNortheastern University\ncassano.f@northeastern.edu\nEdward Berman\nNortheastern University\nberman.ed@northeastern.edu\nAshwin Gopinath\nMassachusetts Institute of Technology\nagopi@mit.edu\nKarthik Narasimhan\nPrinceton University\nkarthikn@princeton.edu\nShunyu Yao\nPrinceton University\nshunyuy@princeton.edu\nAbstract\nLarge language models (LLMs) have been increasingly used to interact with exte
# ...

# %% [markdown]
# 2.

# %%
# 重启 Python 解释器以加载新安装的包
# import sys
# import os
# import importlib

# # 修复 matplotlib 后端问题
# os.environ['MPLBACKEND'] = 'Agg'

# # 清除已缓存的模块
# modules_to_clear = [k for k in sys.modules.keys() if k.startswith(('pdfminer', 'unstructured', 'matplotlib'))]
# for module in modules_to_clear:
#     del sys.modules[module]
    
# print(f"已清除 {len(modules_to_clear)} 个模块缓存")
# Out:
# 已清除 69 个模块缓存

# %%
from langchain_community.document_loaders import UnstructuredPDFLoader

file_path = "../datas/Reflexion.pdf"
loader = UnstructuredPDFLoader(file_path=file_path, mode="elements", strategy="fast")

data = loader.load()

print(data)
# Out:
# ...
# [Document(metadata={'source': '../datas/Reflexion.pdf', 'coordinates': {'points': ((16.34, 218.94000000000005), (16.34, 258.94000000000005), (36.34, 258.94000000000005), (36.34, 218.94000000000005)), 'system': 'PixelSpace', 'layout_width': 612.0, 'layout_height': 792.0}, 'file_directory': '../datas', 'filename': 'Reflexion.pdf', 'last_modified': '2026-01-19T16:10:40', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/pdf', 'category': 'UncategorizedText', 'element_id': '55c77621be05c553a8dba224b63f3e27'}, page_content='3 2 0 2'), Document(metadata={'source': '../datas/Reflexion.pdf', 'coordinates': {'points': ((16.34, 263.94000000000005), (16.34, 317.82000000000005), (36.34, 317.82000000000005), (36.34, 263.94000000000005)), 'system': 'PixelSpace', 'layout_width': 612.0, 'layout_height': 792.0}, 'file_directory': '../datas', 'filename': 'Reflexion.pdf', 'last_modified': '2026-01-19T16:10:40', 'page_number': 1, 'languages': ['eng'], 'filetype': 'application/pdf', 'categ
# ...
