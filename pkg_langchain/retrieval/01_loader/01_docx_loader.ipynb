# %% [markdown]
# 1. Docx2txtLoader

# %%
from langchain_community.document_loaders import Docx2txtLoader

file_path = "../datas/行业.docx"
loader = Docx2txtLoader(file_path=file_path)

data = loader.load()

print(data)
# Out:
# [Document(metadata={'source': '../datas/行业.docx'}, page_content='行业：建筑行业\n\n应用：审标系统\n\n业务场景：\n\n传统招投标流程需人工处理70-100页的招标文件，并生成上百页投标书，耗时耗力。\n\n标书审查环节需逐项核对资质、格式、数据一致性等，易因人为疏漏导致废标。\n\n大模型的解决方案：\n\n招标文件解析：大模型快速解析招标文档，提取核心需求、资质要求等关键信息（5分钟完成人工数天工作）。\n\n标书自动生成：基于招标文件内容，生成符合要求的投标书初稿，减少重复性文字工作。\n\n自动化审查：通过Agent智能体对标书进行合规性检查（如印章有效性、数据一致性），降低废标风险。\n\n\n\n行业：制造业\n\n应用：智能销售系统\n\n业务场景：\n\n产品型号复杂（如洁具、家电），传统销售需查询大量参数文档，响应客户效率低。\n\n客户咨询涉及多维度参数匹配（如尺寸、安装条件），人工处理耗时长。\n\n大模型解决方案：\n\n知识库构建：将产品参数、价格、优惠规则等结构化存入大模型知识库。\n\n智能问答：通过自然语言理解客户需求，实时检索匹配产品并生成推荐方案。\n\n\n\n行业：制造业\n\n应用：中石化设备起控新员工指南\n\n业务场景：\n\n新员工需掌握复杂设备操作流程，但传统培训依赖纸质手册和师傅带教，效率低下。\n\n老员工长期未操作特定设备时，仍需重新查阅资料，影响生产安全。\n\n大模型的解决方案：\n\n知识库整合：将操作手册、视频教程、安全规范等整合为结构化知识库。\n\n智能问答助手：员工通过自然语言提问，系统返回操作步骤、注意事项及关联视频。\n\n\n\n行业：制造业\n\n应用：陪伴机器人（虚拟闺蜜/伴侣）\n\n业务场景：\n\n用户（尤其女性）对情感陪伴需求增长，但通用大模型回复缺乏"人味"（如机械式讲道理）。\n\n需提供个性化、拟人化的情感支持（职场建议、心理疏导）。\n\n大模型的解决方案：\n\n垂直领域微调：收集女性情感对话数据，对大模型进行微调，使其回复更贴近真实闺蜜。\n\n情感识别：通过语义分析识别用户情绪（如孤独、焦虑），动态调整对话策略。\n\n长期记忆：记录用户偏好与历史对话，提供连续性陪伴体验。\n\n\n\n行业：教育行业\n\n应用：智慧校园系统\n\n业务场景：\n\n学生需跨课程获取知识（如普洱茶制作工艺），但资源分散在课件、视频中，检索困难。\n\n选修课时间冲突导致学习机会流失。\n\n大模型的解决方案：\n\n多模态知识库：整合课件、视频、实验数据，构建学科知识图谱。\n\n智能答疑：学生提问后，系统自动关联知识点并推荐学习路径。\n\n主动学习优化：监测知识盲区，爬取外部资源补充知识库，推动教学内容迭代。')]

# %% [markdown]
# 2. UnstructuredWordDocumentLoader

# %%
from langchain_community.document_loaders import UnstructuredWordDocumentLoader

# 需要安装docx
file_path = "../datas/行业.docx"
loader = UnstructuredWordDocumentLoader(file_path=file_path)

data = loader.load()

print(data)
# Out:
# [Document(metadata={'source': '../datas/行业.docx'}, page_content='行业：建筑行业\n\n应用：审标系统\n\n业务场景：\n\n传统招投标流程需人工处理70-100页的招标文件，并生成上百页投标书，耗时耗力。\n\n标书审查环节需逐项核对资质、格式、数据一致性等，易因人为疏漏导致废标。\n\n大模型的解决方案：\n\n招标文件解析：大模型快速解析招标文档，提取核心需求、资质要求等关键信息（5分钟完成人工数天工作）。\n\n标书自动生成：基于招标文件内容，生成符合要求的投标书初稿，减少重复性文字工作。\n\n自动化审查：通过Agent智能体对标书进行合规性检查（如印章有效性、数据一致性），降低废标风险。\n\n行业：制造业\n\n应用：智能销售系统\n\n业务场景：\n\n产品型号复杂（如洁具、家电），传统销售需查询大量参数文档，响应客户效率低。\n\n客户咨询涉及多维度参数匹配（如尺寸、安装条件），人工处理耗时长。\n\n大模型解决方案：\n\n知识库构建：将产品参数、价格、优惠规则等结构化存入大模型知识库。\n\n智能问答：通过自然语言理解客户需求，实时检索匹配产品并生成推荐方案。\n\n行业：制造业\n\n应用：中石化设备起控新员工指南\n\n业务场景：\n\n新员工需掌握复杂设备操作流程，但传统培训依赖纸质手册和师傅带教，效率低下。\n\n老员工长期未操作特定设备时，仍需重新查阅资料，影响生产安全。\n\n大模型的解决方案：\n\n知识库整合：将操作手册、视频教程、安全规范等整合为结构化知识库。\n\n智能问答助手：员工通过自然语言提问，系统返回操作步骤、注意事项及关联视频。\n\n行业：制造业\n\n应用：陪伴机器人（虚拟闺蜜/伴侣）\n\n业务场景：\n\n用户（尤其女性）对情感陪伴需求增长，但通用大模型回复缺乏"人味"（如机械式讲道理）。\n\n需提供个性化、拟人化的情感支持（职场建议、心理疏导）。\n\n大模型的解决方案：\n\n垂直领域微调：收集女性情感对话数据，对大模型进行微调，使其回复更贴近真实闺蜜。\n\n情感识别：通过语义分析识别用户情绪（如孤独、焦虑），动态调整对话策略。\n\n长期记忆：记录用户偏好与历史对话，提供连续性陪伴体验。\n\n行业：教育行业\n\n应用：智慧校园系统\n\n业务场景：\n\n学生需跨课程获取知识（如普洱茶制作工艺），但资源分散在课件、视频中，检索困难。\n\n选修课时间冲突导致学习机会流失。\n\n大模型的解决方案：\n\n多模态知识库：整合课件、视频、实验数据，构建学科知识图谱。\n\n智能答疑：学生提问后，系统自动关联知识点并推荐学习路径。\n\n主动学习优化：监测知识盲区，爬取外部资源补充知识库，推动教学内容迭代。')]

# %% [markdown]
# 2.1 multi

# %%
from langchain_community.document_loaders import UnstructuredWordDocumentLoader

# 需要安装docx
file_path = "../datas/行业.docx"
loader = UnstructuredWordDocumentLoader(file_path=file_path, mode="paged")

data = loader.load()

print(data)
# Out:
# `mode='paged'` is deprecated in favor of the 'by_page' chunking strategy. Learn more about chunking here: https://docs.unstructured.io/open-source/core-functionality/chunking
# [Document(metadata={'source': '../datas/行业.docx', 'category_depth': 0, 'emphasized_text_contents': ['主动学习优化：'], 'emphasized_text_tags': ['b'], 'file_directory': '../datas', 'filename': '行业.docx', 'last_modified': '2026-01-19T16:10:40', 'languages': ['zho'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document'}, page_content='行业：建筑行业\n\n应用：审标系统\n\n业务场景：\n\n传统招投标流程需人工处理70-100页的招标文件，并生成上百页投标书，耗时耗力。\n\n标书审查环节需逐项核对资质、格式、数据一致性等，易因人为疏漏导致废标。\n\n大模型的解决方案：\n\n招标文件解析：大模型快速解析招标文档，提取核心需求、资质要求等关键信息（5分钟完成人工数天工作）。\n\n标书自动生成：基于招标文件内容，生成符合要求的投标书初稿，减少重复性文字工作。\n\n自动化审查：通过Agent智能体对标书进行合规性检查（如印章有效性、数据一致性），降低废标风险。\n\n行业：制造业\n\n应用：智能销售系统\n\n业务场景：\n\n产品型号复杂（如洁具、家电），传统销售需查询大量参数文档，响应客户效率低。\n\n客户咨询涉及多维度参数匹配（如尺寸、安装条件），人工处理耗时长。\n\n大模型解决方案：\n\n知识库构建：将产品参数、价格、优惠规则等结构化存入大模型知识库。\n\n智能问答：通过自然语言理解客户需求，实时检索匹配产品并生成推荐方案。\n\n行业：制造业\n\n应用：中石化设备起控新员工指南\n\n业务场景：\n\n新员工需掌握复杂设备操作流程，但传统培训依赖纸质手册和师傅带教，效率低下。\n\n老员工长期未操作特定设备时，仍需重新查阅资料，影响生产安全。\n\n大模型的解决方案：\n\n知识库整合：将操作手册、视频教程、安全规范等整合为结构化知识库。\n\n智能问答助手：员工通过自然语言提问，系统返回操作步骤、注意事项及关联视频。\n\n行业：制造业\n\n应用：陪伴机器人（虚拟闺蜜/伴侣）\n\n业务场景：\n\n用户（尤其女性）对情感陪伴需求增长，但通用大模型回复缺乏"人味"（如机械式讲道理）。\n\n需提供个性化、拟人化的情感支持（职场建议、心理疏导）。\n\n大模型的解决方案：\n\n垂直领域微调：收集女性情感对话数据，对大模型进行微调，使其回复更贴近真实闺蜜。\n\n情感识别：通过语义分析识别用户情绪（如孤独、焦虑），动态调整对话策略。\n\n长期记忆：记录用户偏好与历史对话，提供连续性陪伴体验。\n\n行业：教育行业\n\n应用：智慧校园系统\n\n业务场景：\n\n学生需跨课程获取知识（如普洱茶制作工艺），但资源分散在课件、视频中，检索困难。\n\n选修课时间冲突导致学习机会流失。\n\n大模型的解决方案：\n\n多模态知识库：整合课件、视频、实验数据，构建学科知识图谱。\n\n智能答疑：学生提问后，系统自动关联知识点并推荐学习路径。\n\n主动学习优化：监测知识盲区，爬取外部资源补充知识库，推动教学内容迭代。\n\n')]
