# %% [markdown]
# 2. RunnableParallel
# 具体应用：对于用户输入的同一个问题，我们想要调用不同的大模型进行回答，用户可以比对不同大模型的回答效果

# %%
from langchain_core.runnables import RunnableParallel
def func1(a1):
    return a1+"__func1_output"
def func2(a2):
    return a2+"__func2_output"

runnable_parallel = RunnableParallel({"key1": func1, "key2": func2})

runnable_parallel.invoke("你好！")
# Out:
# {'key1': '你好！__func1_output', 'key2': '你好！__func2_output'}

# %% [markdown]
# 一次请求多个智能体

# %%
from langchain_deepseek import ChatDeepSeek
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate
import os

# gpt = OpenAI(model="gpt-4o-mini")
ds = ChatDeepSeek(model="deepseek-chat")
qwen = init_chat_model(
    model="qwen-flash",
    model_provider="openai",
    base_url=os.getenv("DASHSCOPE_BASE_URL"),
    api_key=os.getenv("DASHSCOPE_API_KEY"),
)

messages = [
    ("system", "你是我的英语老师"),
    ("user", "{user_question}")
]
message_template = ChatPromptTemplate.from_messages(messages)

runnable_parallel = message_template | RunnableParallel({"deepseek": ds, "qwen": qwen})

runnable_parallel.invoke({"user_question": "purpose 和 propose有什么区别？"})
# Out:
# {'deepseek': AIMessage(content='这是一个很好的问题，因为这两个词看起来有点像，但意思和用法完全不同。\n\n简单来说：\n*   **purpose** 是**名词**，意思是“**目的、意图、用途**”。\n*   **propose** 是**动词**，意思是“**提议、建议、打算**”。\n\n下面我们来详细区分：\n\n### **Purpose (名词) - 目的、意图**\n\n它指的是做某事的原因、目标或某物的功能。\n\n**核心含义：** 为什么做这件事？它的目标是什么？\n\n**例句：**\n1.  **The purpose of this meeting is to discuss the new project.** (这次会议的目的是讨论新项目。)\n2.  **What is the purpose of this tool?** (这个工具是做什么用的？)\n3.  **She feels her life has a clear purpose.** (她觉得自己的生活有明确的目标。)\n4.  **I came here for a specific purpose.** (我来这里是有特定目的的。)\n\n**常用搭配：**\n*   **the purpose of...** (...的目的)\n*   **for the purpose of...** (为了...的目的)\n*   **on purpose** (**故意地**，这是一个非常重要的短语)\n    *   *He broke the vase on purpose.* (他故意打碎了花瓶。)\n\n---\n\n### **Propose (动词) - 提议、建议、打算**\n\n它指的是主动提出一个计划、想法或行动方案供他人考虑，或者表达自己的意图（尤其是在正式场合）。\n\n**核心含义：** 提出一个建议或计划。\n\n**例句：**\n1.  **He proposed a new marketing strategy at the meeting.** (他在会议上提出了一个新的营销策略。)\n2.  **I propose that we take a short break.** (我建议我们休息一下。)\n3.  **How did he propose to you?** (他是怎么向你求婚的？) *这是最著名的用法之一。*\n4.  **The government proposes to build a new hospital.** (政府计划建一所新医院。)\n\n**名词形式：proposal** (提议，建议书，求婚)\n*   *They submitted a business proposal.* (他们提交了一份商业计划书。)\n*   *She said yes to his proposal!* (她答应了他的求婚！)\n\n---\n\n### **记忆技巧与总结**\n\n1.  **词性不同**：最根本的区别。`purpose` 是**名词**，`propose` 是**动词**。\n2.  **核心联想**：\n    *   **purpose** -> 联想到 **“目标”、“为什么”**。\n    *   **propose** -> 联想到 **“提出”、“建议”**，特别是 **“求婚”** 这个经典场景。\n3.  **拼写提醒**：注意 `purpose` 中间是 `-pose-`，而 `propose` 开头是 `pro-`。`propose` 比 `purpose` 多一个字母 `r`。\n\n**简单测试：**\n*   如果你想表达“这次旅行的**目的**是学习”，用 **purpose**。\n*   如果你想表达“我**建议**我们早点出发”，用 **propose**。\n\n希望这个解释能帮助你清晰地区分它们！', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 663, 'prompt_tokens': 15, 'total_tokens': 678, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache', 'id': 'ee19e7fd-f7db-4114-a9cc-4dd5aabc52cb', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bdf27-5b6b-7843-a2f0-fd1addce6556-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 663, 'total_tokens': 678, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}),
#  'qwen': AIMessage(content='很好！这是一个非常棒的问题。虽然 **purpose** 和 **propose** 看起来有点相似（都和“目的”或“提议”有关），但它们在词性、含义和用法上都有明显区别。我们来一步步拆解：\n\n---\n\n### 一、词性不同\n\n| 单词 | 词性 | 中文意思 |\n|------|------|----------|\n| purpose | 名词 (noun) | 目的，意图 |\n| propose | 动词 (verb) | 提议，建议，打算 |\n\n👉 所以：  \n- **purpose** 是一个“名词”，表示“某事的目的”。  \n- **propose** 是一个“动词”，表示“提出某个建议或计划”。\n\n---\n\n### 二、含义与用法对比\n\n#### ✅ **purpose**（名词）——强调“目的”\n指做某件事的**原因或目标**。\n\n🔹 常见搭配：\n- the purpose of this meeting（这次会议的目的）\n- the purpose of life（人生的目的）\n- with a clear purpose（有明确的目标）\n\n📌 例句：\n- The **purpose** of the project is to improve education in rural areas.  \n  这个项目的目的是改善农村地区的教育。\n\n> 💡 注意：**purpose** 不能当动词用，不能说 “I purpose to go.”（错误）\n\n---\n\n#### ✅ **propose**（动词）——强调“提出建议或计划”\n意思是“建议”、“提议”、“打算”。\n\n🔹 常见搭配：\n- propose an idea（提出一个想法）\n- propose marriage（求婚）\n- propose a solution（提出一个解决方案）\n\n📌 例句：\n- She **proposed** a new marketing strategy at the meeting.  \n  她在会议上提出了一个新的营销策略。\n\n> 💡 注意：**propose** 可以用于正式场合，比如开会、求婚、写提案等。\n\n---\n\n### 三、形象比喻帮助记忆\n\n想象你正在策划一场旅行：\n\n- ❓ 你为什么想去？ → **What’s the purpose?**（目的是什么？）\n- 🤔 你打算怎么安排？ → **I propose we go hiking first.**（我建议我们先去徒步。）\n\n👉 所以：\n- **purpose** = 你旅行的“理由”（why）\n- **propose** = 你“建议”的具体行动（what to do）\n\n---\n\n### 四、常见错误提醒\n\n❌ 错误用法：\n- ✘ I purpose to study harder. （× 不能这样用！）\n- ✘ He has no purpose for the plan. （× 应该是 "He has no purpose in the plan"，但更自然的说法是 "He doesn’t see the point of the plan."）\n\n✅ 正确表达：\n- ✅ I **intend** to study harder.（我打算更努力学习。）\n- ✅ He **proposes** a new plan.（他提议了一个新计划。）\n\n---\n\n### ✅ 总结一句话：\n\n> 🔹 **Purpose** 是“目的”（名词），回答“为什么做？”  \n> 🔹 **Propose** 是“提议”（动词），回答“做什么？”或“建议什么？”\n\n---\n\n如果你需要，我可以给你一个小练习巩固一下 😊  \n要不要来一组填空题试试？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 708, 'prompt_tokens': 23, 'total_tokens': 731, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'qwen-flash', 'system_fingerprint': None, 'id': 'chatcmpl-642b7c00-efaa-9f22-9b50-1274c290ce26', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bdf27-5b6c-7fe2-9e7d-7cc4b17bc52a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 708, 'total_tokens': 731, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})}
